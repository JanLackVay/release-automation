# %%
import requests
import yaml

# %%
credentials=yaml.safe_load(open('../credentials/credentials.yaml'))

# %%
response = requests.get("http://conveyor.reeinfra.net/view/Release%20Trigger%20Jobs/job/trigger-long-gamma-test-release/api/json",
        auth=(credentials["username"], credentials["credentials"])).json()
# Out:
# {'_class': 'org.jenkinsci.plugins.workflow.job.WorkflowJob',
#  'actions': [{},
#   {},
#   {},
#   {},
#   {},
#   {},
#   {'_class': 'org.jenkinsci.plugins.displayurlapi.actions.JobDisplayAction'},
#   {},
#   {},
#   {'_class': 'com.cloudbees.plugins.credentials.ViewCredentialsAction'}],
#  'description': None,
#  'displayName': 'Release: Trigger long Gamma test',
#  'displayNameOrNull': 'Release: Trigger long Gamma test',
#  'fullDisplayName': 'Release: Trigger long Gamma test',
#  'fullName': 'trigger-long-gamma-test-release',
#  'name': 'trigger-long-gamma-test-release',
#  'url': 'http://jenkins-ber.reeinfra.net/view/Release%20Trigger%20Jobs/job/trigger-long-gamma-test-release/',
#  'buildable': True,
#  'builds': [{'_class': 'org.jenkinsci.plugins.workflow.job.WorkflowRun',
#    'number': 3741,
#    'url': 'http://jenkins-ber.reeinfra.net/view/Release%20Trigger%20Jobs/job/trigger-long-gamma-test-release/3741/'},
# ...
